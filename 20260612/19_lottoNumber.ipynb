# %%
import random
lotto = [i for i in range(1, 46)]

# %% [markdown]
# 로또 복권 구매 금액을 입력받아 입력받은 금액만큼 로또 번호를 생성한다.

# %%
# 로또 복권 구매 금액을 입력받는다.
money = int(input('로또 복권 구매 금액을 입력하세요: '))
# 로또 번호 구매 금액만큼 반복하며 로또 번호를 생성한다.
for i in range(money // 1000):
    random.shuffle(lotto)
    print('{:3d} game: '.format(i + 1), end='')
    result = lotto[:6]
    result.sort()
    for j in range(6):
        print('{:02d}'.format(result[j]), end=' ')
    # ===== for j
    print()
# ===== for i

# %%
money = int(input('로또 복권 구매 금액을 입력하세요: '))
for i in range(money // 1000):
    # random.shuffle(lotto)
    print('{:3d} game: '.format(i + 1), end='')
    # result = lotto[:6]
    result = random.sample(lotto, 6)
    result.sort()
    for j in range(6):
        print('{:02d}'.format(result[j]), end=' ')
    # ===== for j
    print()
# ===== for i
