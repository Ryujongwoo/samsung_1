# %%
import warnings
warnings.filterwarnings("ignore")
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\enjoy\AppData\Local\Temp\ipykernel_13040\57172117.py:4: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.
#
# WARNING:tensorflow:From C:\python11\Lib\site-packages\tensorflow\python\compat\v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# placeholder는 tensorflow에서 사용할 여러건의 데이터를 저장하는 배열의 일종이다.
#
# placeholder(dtype[, shape, name])
# dtype: placeholder에 저장되는 데이터의 자료형
# shape: placeholder에 저장되는 데이터의 차원, 생략가능
# name: placeholder의 이름, 생략가능

# %%
# placeholder에 저장할 데이터를 선언한다.
xData = [1, 2, 3, 4, 5]
yData = [5, 4, 3, 2, 1]

# placeholder() 메소드로 tensorflow 사용할 placeholder를 선언한다.
x = tf.placeholder(dtype=tf.float64) # xData의 데이터를 기억할 placeholder를 선언한다.
y = tf.placeholder(dtype=tf.float64) # yData의 데이터를 기억할 placeholder를 선언한다.
print('x = {}'.format(x))
print('y = {}'.format(y))

# placeholder를 사용하는 수식을 만든다.
z = x + y
print('z = {}'.format(z))

sess = tf.Session()
# 아래와 같이 수식을 실행하면 x, y placeholder에 데이터가 채워지지 않아서 에러가 발생된다.
# result = sess.run(z) # 에러

# placeholder를 사용하는 수식은 반드시 수식에 사용할 데이터를 placeholder에 대입한 후 실행해야 한다.
# placeholder에 대입하는 방법은 feed_dict 속성에 딕셔너리 형태로 {placeholder: 데이터, placeholder: 데이터, ...}와 같은 방식을 사용한다.
result = sess.run(z, feed_dict={x: xData, y:yData})
print(result)
# Out:
# x = Tensor("Placeholder_13:0", dtype=float64)
# y = Tensor("Placeholder_14:0", dtype=float64)
# z = Tensor("add_5:0", dtype=float64)
# [6. 6. 6. 6. 6.]
