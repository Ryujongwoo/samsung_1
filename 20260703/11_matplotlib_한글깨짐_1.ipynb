# %%
import warnings
warnings.filterwarnings(action='ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm
# 한글 폰트를 사용할 때 마이너스 부호가 깨져보이는 문제에 대처한다.
mpl.rcParams['axes.unicode_minus'] = False

# %%
data = np.random.randint(-100, 100, 50).cumsum()
print(data)
# Out:
# [ -70 -119  -48   -3   84   -7  -52  -48  -26   43   47  134  184  145
#   131  124   94   90   31   73  -23  -89  -46   29   -2 -100 -161  -71
#  -140 -169 -140 -115 -150 -193 -251 -207 -184 -276 -177 -271 -250 -285
#  -317 -275 -184 -143 -154 -230 -260 -221]

# %%
# plt.figure(figsize=[6, 4]) # 차트 크기 설정
plt.rcParams['figure.figsize'] = [8, 6] # 차트 크기 설정
plt.plot(range(1, 51), data, 'ro--')
plt.title('시간별 가격 추이') # 차트 제목
plt.xlabel('시간') # x축 제목
plt.ylabel('가격') # y축 제목
plt.show()

# %% [markdown]
# 한글 폰트를 설정하기 앞서서 설치된 matplotlib의 버전과 설치된 위치 정보를 확인한다.

# %%
print('버전: {}'.format(mpl.__version__))
print('설치 경로: {}'.format(mpl.__file__))
print('환경 설정 정보 경로: {}'.format(mpl.get_configdir()))
print('캐시 경로: {}'.format(mpl.get_cachedir()))
# Out:
# 버전: 3.11.0
# 설치 경로: C:\python11\Lib\site-packages\matplotlib\__init__.py
# 환경 설정 정보 경로: C:\Users\enjoy\.matplotlib
# 캐시 경로: C:\Users\enjoy\.matplotlib

# %% [markdown]
# matplotlib의 설정 위치 정보를 알았으니 설정 파일 위치를 확인한다.

# %%
print('설정 파일 경로: {}'.format(mpl.matplotlib_fname()))
# Out:
# 설정 파일 경로: C:\python11\Lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %% [markdown]
# 컴퓨터에 설치된 폰트 목록을 얻어온다.

# %%
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')
print(len(font_list))
print(font_list[:10])
# Out:
# 373
# ['C:\\Windows\\Fonts\\calibrib.ttf', 'C:\\Windows\\Fonts\\GILLUBCD.TTF', 'C:\\Windows\\Fonts\\georgiaz.ttf', 'C:\\Windows\\Fonts\\TCCM____.TTF', 'C:\\Windows\\Fonts\\CASTELAR.TTF', 'C:\\Windows\\Fonts\\corbelz.ttf', 'C:\\Windows\\Fonts\\BOD_B.TTF', 'C:\\Windows\\Fonts\\FRAMDCN.TTF', 'C:\\Windows\\Fonts\\LBRITE.TTF', 'C:\\Windows\\Fonts\\corbeli.ttf']

# %%
font_name = [f.name for f in fm.fontManager.ttflist]
print(len(font_name))
print(font_name[:10])
# Out:
# 492
# ['DejaVu Serif', 'DejaVu Sans Mono', 'STIXSizeTwoSym', 'STIXSizeTwoSym', 'cmsy10', 'STIXNonUnicode', 'STIXNonUnicode', 'DejaVu Sans', 'STIXNonUnicode', 'DejaVu Sans']

# %% [markdown]
# 나눔 글꼴을 사용할 것이므로 폰트 이름에 'Nanum'이 포함된 폰트만 가져온다.

# %%
font_name = [(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
font_name
# Out:
# [('NanumGothicCoding',
#   'C:\\Users\\enjoy\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothicCoding.ttf'),
#  ('NanumGothicCoding',
#   'C:\\Users\\enjoy\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothicCoding-Bold.ttf')]

# %% [markdown]
# 위의 코드를 실행한 결과가 []만 나오거나 폰트를 설치했는데 설치한 폰트가 보이지 않는다면 캐시 폴더로 이동해 모든 파일을 삭제하고 다시 실행하면 폰트 목록이 정상적으로 보인다.
#
# 한글 폰트를 사용하도록 설정하는 방법은 4가지가 있다.
#
# ① FontProperties를 사용하는 방법 => 그래프에 폰트가 필요한 항목마다 일일히 개별적으로 설정한다.
# matplotlib.pyplot => title(), xlabel(), ylabel(), legend(), text()
# matplotlib => set_title()

# %%
font = 'C:\\Users\\enjoy\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothicCoding.ttf'
# FontProperties(글꼴경로, 글꼴크기)
fontprop = fm.FontProperties(fname=font, size=15)

# %%
plt.figure(figsize=[8, 6])
plt.plot(range(1, 51), data, 'ro--')
plt.title('시간별 가격 추이', fontproperties=fontprop)
plt.xlabel('시간', fontproperties=fontprop)
plt.ylabel('가격', fontproperties=fontprop)
plt.show()
