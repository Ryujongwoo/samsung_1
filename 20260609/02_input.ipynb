# %% [markdown]
# 변수(variable)
# 변수는 처리할 데이터(상수, constant)를 기억하는 기억장소를 말한다.
#
# 변수명 작성방법
# 영문자(대소문자를 구분한다.), 숫자, 특수문자('_'만 사용 가능하다.)를 사용할 수 있으며 반드시 문자로 시작해야 한다.
# 예약어(파이썬과 약속된 단어 => 명령어, 함수 등)는 변수 이름으로 사용할 수 없다.
#
# 파이썬은 C/C++이나 JAVA와 같이 변수 선언시 자료형을 지정하지 않고 JavaScript 처럼 변수 선언시 var, let, const를 붙이지 않고 변수를 선언한다.
# 변수에 저장되는 데이터의 타입에 따라서 자동으로 변수의 자료형이 결정된다.
#
# '='는 같다라는 의미로 사용되지 않고 '=' 오른쪽의 데이터를 '=' 왼쪽의 기억장소에 저장하라는 의미이다. => 대입문, 할당문, 배정문
# '=='와 같이 2개를 연속해서 사용해야 같다로 인식한다.

# %%
a = '홍길동'
print(a)
# type() 함수는 인수로 지정된 데이터의 자료형을 얻어온다.
print(type(a)) # <class 'str'> => 문자열

a = 100
print(a)
print(type(a)) # <class 'int'> => 정수

a = 3.14
print(a)
print(type(a)) # <class 'float'> => 실수

# True => 참, False => 거짓, 반드시 첫 문자는 대문자로 나머지는 소문자로 사용해야 한다.
a = True
print(a)
print(type(a)) # <class 'bool'> => 논리값
# Out:
# 홍길동
# <class 'str'>
# 100
# <class 'int'>
# 3.14
# <class 'float'>
# True
# <class 'bool'>

# %%
print(a)
# 파이썬은 프로그램이 종료되야 기억장소가 메모리에서 소멸된다.
# 프로그램 실행 도중에 더 이상 사용할 필요없는 기억장소는 del 명령어로 메모리에서 삭제할 수 있다.
del a
print(a)
# Out:
# True
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 print(a)
#       2 del a
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# input 함수
#
# 키보드로 입력하는 데이터를 무조건 문자열 형태로 입력받는다.
# 변수 = input(['메시지'])

# %%
name = input('이름을 입력하세요: ')
print(name)
print(type(name))
print('%s님 안녕하세요' % name)
print('{:s}님 안녕하세요'.format(name))
print(f'{name}님 안녕하세요')
# Out:
# 이름을 입력하세요: 임꺽정
# 임꺽정
# <class 'str'>
# 임꺽정님 안녕하세요
# 임꺽정님 안녕하세요
# 임꺽정님 안녕하세요

# %% [markdown]
# input() 함수는 무조건 문자열 형태로 데이터를 입력받기 때문에 정수나 실수 형태의 데이터를 입력받으려면 입력받은 데이터를 int() 함수나 float() 함수를 사용해서 숫자로 변환시켜 사용한다.

# %%
age = int(input('나이를 입력하세요: '))
print(age)
print(type(age))
print('%s님은 %d살 입니다.' % (name, age))
print('{:s}님은 {:d}살 입니다.'.format(name, age))
print('{:s}님은 내년에 {:d}살 입니다.'.format(name, age + 1))
# Out:
# 나이를 입력하세요: 19
# 19
# <class 'int'>
# 임꺽정님은 19살 입니다.
# 임꺽정님은 19살 입니다.
# 임꺽정님은 내년에 20살 입니다.

# %% [markdown]
# split() 메소드를 사용하면 1개의 input() 함수로 여러개의 문자열 데이터를 입력받을 수 있다.
# split() 메소드는 인수로 지정한 구분자를 사용해서 문자열을 나눠준다. 구분자를 생략하면 공백이 기본 구분자로 사용된다.

# %%
name, age = input('이름과 나이를 입력하세요: ').split()
print('{:s}님은 {:d}살 입니다.'.format(name, int(age)))
print('{:s}님은 내년에 {:d}살 입니다.'.format(name, int(age) + 1))
# Out:
# 이름과 나이를 입력하세요: 홍길동 20
# 홍길동님은 20살 입니다.
# 홍길동님은 내년에 21살 입니다.

# %%
name, age = input('이름과 나이를 입력하세요: ').split(' ')
print('{:s}님은 {:d}살 입니다.'.format(name, int(age)))
print('{:s}님은 내년에 {:d}살 입니다.'.format(name, int(age) + 1))
# Out:
# 이름과 나이를 입력하세요: 임꺽정 30
# 임꺽정님은 30살 입니다.
# 임꺽정님은 내년에 31살 입니다.

# %%
name, age = input('이름과 나이를 입력하세요: ').split(',')
print('{:s}님은 {:d}살 입니다.'.format(name, int(age)))
print('{:s}님은 내년에 {:d}살 입니다.'.format(name, int(age) + 1))
# Out:
# 이름과 나이를 입력하세요: 장길산,40
# 장길산님은 40살 입니다.
# 장길산님은 내년에 41살 입니다.

# %%
java, jsp, python = input('3과목 점수를 입력하세요: ').split()
# total = java + jsp + python # 10010099
total = int(java) + int(jsp) + int(python)
print('총점: {}, 평균: {:.2f}'.format(total, total / 3))
# Out:
# 세 과목 점수를 입력하세요: 100 100 99
# 총점: 299, 평균: 99.67

# %% [markdown]
# map() 함수를 사용하면 입력받은 데이터를 split() 메소드로 구분한 수 일괄적으로 형변환 시킬 수 있다.
# map(자료형, input('메시지').split())

# %%
java, jsp, python = map(int, input('3과목 점수를 입력하세요: ').split())
total = java + jsp + python
print('총점: {}, 평균: {:.2f}'.format(total, total / 3))
# Out:
# 3과목 점수를 입력하세요: 100 100 99
# 총점: 299, 평균: 99.67
