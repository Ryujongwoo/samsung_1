# %% [markdown]
# selection sort(선택 정렬, 교환법) 알고리즘
#
# 선택 정렬은 i번째 데이터를 선택해서 나머지 데이터(j번째)와 비교하며 정렬한다.
# 정렬할 데이터가 n개일 경우 회전수는 n-1번이 된다. => 데이터가 5개면 회전수는 4번이다.
#
# <img src="selectionSort1.png" width="1000" align="left" />

# %% [markdown]
# <img src="selectionSort2.png" width="1000" align="left" />

# %% [markdown]
# <img src="selectionSort3.png" width="1000" align="left" />

# %%
n = 5
for i in range(n - 1):
    for j in range(i + 1, n):
        print(f'[i = {i}, j = {j}]', end='')
    print()
# Out:
# [i = 0, j = 1][i = 0, j = 2][i = 0, j = 3][i = 0, j = 4]
# [i = 1, j = 2][i = 1, j = 3][i = 1, j = 4]
# [i = 2, j = 3][i = 2, j = 4]
# [i = 3, j = 4]

# %%
data = [8, 3, 4, 9, 1]
for i in range(n - 1):
    for j in range(i + 1, n):
        if data[i] < data[j]:
            data[i], data[j] = data[j], data[i]
        # ===== if
    # ===== for j
# ===== for i
print(data)
# Out:
# [9, 8, 4, 3, 1]
