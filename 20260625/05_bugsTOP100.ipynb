# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
print(dt.now())
# Out:
# 2026-06-25 11:21:11.136517

# %%
targetSite = 'https://music.bugs.co.kr/chart'
request = requests.get(targetSite)
# print(request)
html = request.text
soup = BeautifulSoup(html, 'html.parser')
# print(soup)

# %% [markdown]
# 노래 제목 크롤링

# %%
titles = soup.findAll('p', {'class': 'title'})
# print(len(titles))
# print(titles)

for i in range(len(titles)):
    # print('{:3d}위 {}'.format(i + 1, titles[i].text.strip()))
    # print('{:3d}위 {}'.format(i + 1, titles[i].text.split('\n')[1]))
    print('{:3d}위 {}'.format(i + 1, titles[i].text.strip().split('\n')[0]))
# Out:
#   1위 Ride or Die
#   2위 갑자기
#   3위 REDRED
#   4위 LEMONADE
#   5위 LOVE ATTACK
#   6위 It′s Me
#   7위 소문의 낙원
#   8위 Drowning
#   9위 캐치 캐치
#  10위 사랑하게 될 거야
#  11위 생각을 멈추다 보면
#  12위 WDA (Whole Different Animal) (Feat. G-DRAGON)
#  13위 0+0
#  14위 RUDE!
#  15위 Heavy Serenade
#  16위 Good Goodbye
#  17위 Lemon Tang
#  18위 기쁨, 슬픔, 아름다운 마음
#  19위 Popcorn
#  20위 BANG BANG
#  21위 BOOMPALA
#  22위 404 (New Era)
#  23위 봄 내음보다 너를
#  24위 타임캡슐
#  25위 BUMPA
#  26위 입춘
#  27위 너에게 닿기를
#  28위 멸종위기사랑
#  29위 toxic till the end
#  30위 한 페이지가 될 수 있게
#  31위 Who is she
#  32위 Golden
#  33위 뛰어(JUMP)
#  34위 Whiplash
#  35위 like JENNIE
#  36위 So Cute
#  37위 Do your dance
#  38위 Blue Valentine
#  39위 내게 사랑이 뭐냐고 물어본다면
#  40위 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  41위 청춘만화
#  42위 HAPPY
#  43위 사랑은 봄비처럼... 이별은 겨울비처럼
#  44위 띠로리 (DDI RO RI)
#  45위 소나기
#  46위 APT.
#  47위 모든 날, 모든 순간 (Every day, Every Moment)
#  48위 THAT’S A NO NO
#  49위 BLACKHOLE
#  50위 고민중독
#  51위 Deja Vu
#  52위 Flashback
#  53위 주저하는 연인들을 위해
#  54위 SWIM
#  55위 Magnetic
#  56위 그대 작은 나의 세상이 되어
#  57위 Hype Boy
#  58위 에피소드
#  59위 예뻤어
#  60위 마치 오늘처럼
#  61위 천상연
#  62위 Ditto
#  63위 Congratulations
#  64위 Die With A Smile
#  65위 Supernova
#  66위 사랑인가 봐
#  67위 OVERDRIVE
#  68위 달리 표현할 수 없어요
#  69위 FAMOUS
#  70위 나의 하루처럼
#  71위 SPAGHETTI (feat. j-hope of BTS)
#  72위 모르시나요(PROD.로코베리)
#  73위 HOME SWEET HOME (feat. 태양, 대성)
#  74위 나는 반딧불
#  75위 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
#  76위 I AM
#  77위 Love me or Leave me
#  78위 ONE MORE TIME
#  79위 FOCUS
#  80위 GO
#  81위 Welcome to the Show
#  82위 LIVE FAST DIE SLOW
#  83위 Runaway
#  84위 Body to Body
#  85위 Soda Pop
#  86위 춤 (CHOOM)
#  87위 시작의 아이 ❍
#  88위 REBEL HEART
#  89위 첫 만남은 계획대로 되지 않아
#  90위 HOT
#  91위 Flower
#  92위 오늘만 I LOVE YOU
#  93위 I DO ME
#  94위 하루에 하루만 더 (Stick With You)
#  95위 NOT CUTE ANYMORE
#  96위 봄 색깔
#  97위 XOXZ
#  98위 STYLE
#  99위 Love is
# 100위 Love wins all

# %% [markdown]
# 아티스트 크롤링

# %%
artists = soup.findAll('p', {'class': 'artist'})
# print(len(artists))
# print(artists)

for i in range(len(artists)):
    # print('{:3d}위 {}'.format(i + 1, artists[i].text.strip())) # 적절 X
    # print('{:3d}위 {}'.format(i + 1, artists[i].text.split('\n')[1])) # 적절 X
    print('{:3d}위 {}'.format(i + 1, artists[i].text.strip().split('\n')[0]))
# Out:
#   1위 에반(EVAN)
#   2위 아이오아이(I.O.I)
#   3위 CORTIS (코르티스)
#   4위 aespa
#   5위 RESCENE (리센느)
#   6위 아일릿(ILLIT)
#   7위 AKMU(악뮤)
#   8위 WOODZ
#   9위 YENA (최예나)
#  10위 한로로
#  11위 최유리
#  12위 aespa
#  13위 한로로
#  14위 Hearts2Hearts (하츠투하츠)
#  15위 NMIXX
#  16위 화사 (HWASA)
#  17위 Hearts2Hearts (하츠투하츠)
#  18위 AKMU(악뮤)
#  19위 도경수(D.O.)
#  20위 IVE (아이브)
#  21위 LE SSERAFIM (르세라핌)
#  22위 KiiiKiii (키키)
#  23위 김나영
#  24위 다비치
#  25위 비비(BIBI)
#  26위 한로로
#  27위 10CM
#  28위 이찬혁
#  29위 로제(ROSÉ)
#  30위 DAY6 (데이식스)
#  31위 KISS OF LIFE
#  32위 HUNTR/X
#  33위 BLACKPINK
#  34위 aespa
#  35위 제니 (JENNIE)
#  36위 화사 (HWASA)
#  37위 RIIZE
#  38위 NMIXX
#  39위 로이킴
#  40위 AKMU(악뮤)
#  41위 이무진
#  42위 DAY6 (데이식스)
#  43위 임현정
#  44위 MEOVV (미야오)
#  45위 이클립스 (ECLIPSE)
#  46위 로제(ROSÉ)
#  47위 폴킴(Paul Kim)
#  48위 ITZY (있지)
#  49위 IVE (아이브)
#  50위 QWER
#  51위 RESCENE (리센느)
#  52위 엔플라잉(N.Flying)
#  53위 잔나비
#  54위 방탄소년단
#  55위 아일릿(ILLIT)
#  56위 카더가든
#  57위 NewJeans
#  58위 이무진
#  59위 DAY6 (데이식스)
#  60위 정승환
#  61위 이창섭
#  62위 NewJeans
#  63위 DAY6 (데이식스)
#  64위 Lady Gaga(레이디 가가)
#  65위 aespa
#  66위 멜로망스(MeloMance)
#  67위 TWS (투어스)
#  68위 로이킴
#  69위 ALLDAY PROJECT
#  70위 성시경
#  71위 LE SSERAFIM (르세라핌)
#  72위 조째즈
#  73위 G-DRAGON
#  74위 황가람
#  75위 너드커넥션(Nerd Connection)
#  76위 IVE (아이브)
#  77위 DAY6 (데이식스)
#  78위 ALLDAY PROJECT
#  79위 Hearts2Hearts (하츠투하츠)
#  80위 BLACKPINK
#  81위 DAY6 (데이식스)
#  82위 태양
#  83위 RESCENE (리센느)
#  84위 방탄소년단
#  85위 Saja Boys
#  86위 BABYMONSTER
#  87위 박다혜
#  88위 IVE (아이브)
#  89위 TWS (투어스)
#  90위 LE SSERAFIM (르세라핌)
#  91위 오반(OVAN)
#  92위 BOYNEXTDOOR
#  93위 KiiiKiii (키키)
#  94위 투모로우바이투게더
#  95위 아일릿(ILLIT)
#  96위 AKMU(악뮤)
#  97위 IVE (아이브)
#  98위 Hearts2Hearts (하츠투하츠)
#  99위 트라이앵글
# 100위 아이유(IU)

# %%
print(dt.now())
for i in range(len(titles)):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    print('{:3d}위 {} - {}'.format(i + 1, artist, title))
# Out:
# 2026-06-25 11:35:28.937703
#   1위 에반(EVAN) - Ride or Die
#   2위 아이오아이(I.O.I) - 갑자기
#   3위 CORTIS (코르티스) - REDRED
#   4위 aespa - LEMONADE
#   5위 RESCENE (리센느) - LOVE ATTACK
#   6위 아일릿(ILLIT) - It′s Me
#   7위 AKMU(악뮤) - 소문의 낙원
#   8위 WOODZ - Drowning
#   9위 YENA (최예나) - 캐치 캐치
#  10위 한로로 - 사랑하게 될 거야
#  11위 최유리 - 생각을 멈추다 보면
#  12위 aespa - WDA (Whole Different Animal) (Feat. G-DRAGON)
#  13위 한로로 - 0+0
#  14위 Hearts2Hearts (하츠투하츠) - RUDE!
#  15위 NMIXX - Heavy Serenade
#  16위 화사 (HWASA) - Good Goodbye
#  17위 Hearts2Hearts (하츠투하츠) - Lemon Tang
#  18위 AKMU(악뮤) - 기쁨, 슬픔, 아름다운 마음
#  19위 도경수(D.O.) - Popcorn
#  20위 IVE (아이브) - BANG BANG
#  21위 LE SSERAFIM (르세라핌) - BOOMPALA
#  22위 KiiiKiii (키키) - 404 (New Era)
#  23위 김나영 - 봄 내음보다 너를
#  24위 다비치 - 타임캡슐
#  25위 비비(BIBI) - BUMPA
#  26위 한로로 - 입춘
#  27위 10CM - 너에게 닿기를
#  28위 이찬혁 - 멸종위기사랑
#  29위 로제(ROSÉ) - toxic till the end
#  30위 DAY6 (데이식스) - 한 페이지가 될 수 있게
#  31위 KISS OF LIFE - Who is she
#  32위 HUNTR/X - Golden
#  33위 BLACKPINK - 뛰어(JUMP)
#  34위 aespa - Whiplash
#  35위 제니 (JENNIE) - like JENNIE
#  36위 화사 (HWASA) - So Cute
#  37위 RIIZE - Do your dance
#  38위 NMIXX - Blue Valentine
#  39위 로이킴 - 내게 사랑이 뭐냐고 물어본다면
#  40위 AKMU(악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  41위 이무진 - 청춘만화
#  42위 DAY6 (데이식스) - HAPPY
#  43위 임현정 - 사랑은 봄비처럼... 이별은 겨울비처럼
#  44위 MEOVV (미야오) - 띠로리 (DDI RO RI)
#  45위 이클립스 (ECLIPSE) - 소나기
#  46위 로제(ROSÉ) - APT.
#  47위 폴킴(Paul Kim) - 모든 날, 모든 순간 (Every day, Every Moment)
#  48위 ITZY (있지) - THAT’S A NO NO
#  49위 IVE (아이브) - BLACKHOLE
#  50위 QWER - 고민중독
#  51위 RESCENE (리센느) - Deja Vu
#  52위 엔플라잉(N.Flying) - Flashback
#  53위 잔나비 - 주저하는 연인들을 위해
#  54위 방탄소년단 - SWIM
#  55위 아일릿(ILLIT) - Magnetic
#  56위 카더가든 - 그대 작은 나의 세상이 되어
#  57위 NewJeans - Hype Boy
#  58위 이무진 - 에피소드
#  59위 DAY6 (데이식스) - 예뻤어
#  60위 정승환 - 마치 오늘처럼
#  61위 이창섭 - 천상연
#  62위 NewJeans - Ditto
#  63위 DAY6 (데이식스) - Congratulations
#  64위 Lady Gaga(레이디 가가) - Die With A Smile
#  65위 aespa - Supernova
#  66위 멜로망스(MeloMance) - 사랑인가 봐
#  67위 TWS (투어스) - OVERDRIVE
#  68위 로이킴 - 달리 표현할 수 없어요
#  69위 ALLDAY PROJECT - FAMOUS
#  70위 성시경 - 나의 하루처럼
#  71위 LE SSERAFIM (르세라핌) - SPAGHETTI (feat. j-hope of BTS)
#  72위 조째즈 - 모르시나요(PROD.로코베리)
#  73위 G-DRAGON - HOME SWEET HOME (feat. 태양, 대성)
#  74위 황가람 - 나는 반딧불
#  75위 너드커넥션(Nerd Connection) - 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
#  76위 IVE (아이브) - I AM
#  77위 DAY6 (데이식스) - Love me or Leave me
#  78위 ALLDAY PROJECT - ONE MORE TIME
#  79위 Hearts2Hearts (하츠투하츠) - FOCUS
#  80위 BLACKPINK - GO
#  81위 DAY6 (데이식스) - Welcome to the Show
#  82위 태양 - LIVE FAST DIE SLOW
#  83위 RESCENE (리센느) - Runaway
#  84위 방탄소년단 - Body to Body
#  85위 Saja Boys - Soda Pop
#  86위 BABYMONSTER - 춤 (CHOOM)
#  87위 박다혜 - 시작의 아이 ❍
#  88위 IVE (아이브) - REBEL HEART
#  89위 TWS (투어스) - 첫 만남은 계획대로 되지 않아
#  90위 LE SSERAFIM (르세라핌) - HOT
#  91위 오반(OVAN) - Flower
#  92위 BOYNEXTDOOR - 오늘만 I LOVE YOU
#  93위 KiiiKiii (키키) - I DO ME
#  94위 투모로우바이투게더 - 하루에 하루만 더 (Stick With You)
#  95위 아일릿(ILLIT) - NOT CUTE ANYMORE
#  96위 AKMU(악뮤) - 봄 색깔
#  97위 IVE (아이브) - XOXZ
#  98위 Hearts2Hearts (하츠투하츠) - STYLE
#  99위 트라이앵글 - Love is
# 100위 아이유(IU) - Love wins all

# %% [markdown]
# 크롤링한 결과를 텍스트 파일에 저장한다.

# %%
# file = open('D:\\samsung_1\\python\\web_crawing\\workspace\\output\\bugsTOP100.txt', 'w') # 절대경로
# file = open('D:/samsung_1/python/web_crawing/workspace/output/bugsTOP100.txt', 'w') # 절대경로
# file = open('./output/bugsTOP100.txt', 'w') # 상대경로
# 위의 open() 함수와 같이 파일을 열때 'cp949~~~' 에러가 발생되면 아래와 같이 open 한다.
file = open('./output/bugsTOP100.txt', 'w', -1, 'utf-8')
# file.write(str(dt.now()) + '\n')
file.write(dt.now().strftime('%Y-%m-%d %H:%M:%S') + '\n')
for i in range(len(titles)):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    file.write('{:3d}위 {} - {}\n'.format(i + 1, artist, title))
file.close()
print('bugsTOP100.txt 파일로 쓰기 완료')
# Out:
# bugsTOP100.txt 파일로 쓰기 완료

# %%
with open('./output/bugsTOP100.txt', 'w', -1, 'utf-8') as file:
    file.write(dt.now().strftime('%Y-%m-%d %H:%M:%S') + '\n')
    for i in range(len(titles)):
        artist = artists[i].text.strip().split('\n')[0]
        title = titles[i].text.strip().split('\n')[0]
        file.write('{:3d}위 {} - {}\n'.format(i + 1, artist, title))
print('bugsTOP100.txt 파일로 쓰기 완료')
# Out:
# bugsTOP100.txt 파일로 쓰기 완료

# %% [markdown]
# 텍스트 파일에 저장된 데이터를 읽어서 화면에 출력한다.

# %%
try:
    file = open('./output/bugsTOP100.txt', 'r', -1, 'utf-8')
    lines = file.readlines()
    for line in lines:
        print(line.strip())
except FileNotFoundError:
    print('디스크에 파일이 없습니다.')
# Out:
# 2026-06-25 12:04:45
# 1위 에반(EVAN) - Ride or Die
# 2위 아이오아이(I.O.I) - 갑자기
# 3위 CORTIS (코르티스) - REDRED
# 4위 aespa - LEMONADE
# 5위 RESCENE (리센느) - LOVE ATTACK
# 6위 아일릿(ILLIT) - It′s Me
# 7위 AKMU(악뮤) - 소문의 낙원
# 8위 WOODZ - Drowning
# 9위 YENA (최예나) - 캐치 캐치
# 10위 한로로 - 사랑하게 될 거야
# 11위 최유리 - 생각을 멈추다 보면
# 12위 aespa - WDA (Whole Different Animal) (Feat. G-DRAGON)
# 13위 한로로 - 0+0
# 14위 Hearts2Hearts (하츠투하츠) - RUDE!
# 15위 NMIXX - Heavy Serenade
# 16위 화사 (HWASA) - Good Goodbye
# 17위 Hearts2Hearts (하츠투하츠) - Lemon Tang
# 18위 AKMU(악뮤) - 기쁨, 슬픔, 아름다운 마음
# 19위 도경수(D.O.) - Popcorn
# 20위 IVE (아이브) - BANG BANG
# 21위 LE SSERAFIM (르세라핌) - BOOMPALA
# 22위 KiiiKiii (키키) - 404 (New Era)
# 23위 김나영 - 봄 내음보다 너를
# 24위 다비치 - 타임캡슐
# 25위 비비(BIBI) - BUMPA
# 26위 한로로 - 입춘
# 27위 10CM - 너에게 닿기를
# 28위 이찬혁 - 멸종위기사랑
# 29위 로제(ROSÉ) - toxic till the end
# 30위 DAY6 (데이식스) - 한 페이지가 될 수 있게
# 31위 KISS OF LIFE - Who is she
# 32위 HUNTR/X - Golden
# 33위 BLACKPINK - 뛰어(JUMP)
# 34위 aespa - Whiplash
# 35위 제니 (JENNIE) - like JENNIE
# 36위 화사 (HWASA) - So Cute
# 37위 RIIZE - Do your dance
# 38위 NMIXX - Blue Valentine
# 39위 로이킴 - 내게 사랑이 뭐냐고 물어본다면
# 40위 AKMU(악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 41위 이무진 - 청춘만화
# 42위 DAY6 (데이식스) - HAPPY
# 43위 임현정 - 사랑은 봄비처럼... 이별은 겨울비처럼
# 44위 MEOVV (미야오) - 띠로리 (DDI RO RI)
# 45위 이클립스 (ECLIPSE) - 소나기
# 46위 로제(ROSÉ) - APT.
# 47위 폴킴(Paul Kim) - 모든 날, 모든 순간 (Every day, Every Moment)
# 48위 ITZY (있지) - THAT’S A NO NO
# 49위 IVE (아이브) - BLACKHOLE
# 50위 QWER - 고민중독
# 51위 RESCENE (리센느) - Deja Vu
# 52위 엔플라잉(N.Flying) - Flashback
# 53위 잔나비 - 주저하는 연인들을 위해
# 54위 방탄소년단 - SWIM
# 55위 아일릿(ILLIT) - Magnetic
# 56위 카더가든 - 그대 작은 나의 세상이 되어
# 57위 NewJeans - Hype Boy
# 58위 이무진 - 에피소드
# 59위 DAY6 (데이식스) - 예뻤어
# 60위 정승환 - 마치 오늘처럼
# 61위 이창섭 - 천상연
# 62위 NewJeans - Ditto
# 63위 DAY6 (데이식스) - Congratulations
# 64위 Lady Gaga(레이디 가가) - Die With A Smile
# 65위 aespa - Supernova
# 66위 멜로망스(MeloMance) - 사랑인가 봐
# 67위 TWS (투어스) - OVERDRIVE
# 68위 로이킴 - 달리 표현할 수 없어요
# 69위 ALLDAY PROJECT - FAMOUS
# 70위 성시경 - 나의 하루처럼
# 71위 LE SSERAFIM (르세라핌) - SPAGHETTI (feat. j-hope of BTS)
# 72위 조째즈 - 모르시나요(PROD.로코베리)
# 73위 G-DRAGON - HOME SWEET HOME (feat. 태양, 대성)
# 74위 황가람 - 나는 반딧불
# 75위 너드커넥션(Nerd Connection) - 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
# 76위 IVE (아이브) - I AM
# 77위 DAY6 (데이식스) - Love me or Leave me
# 78위 ALLDAY PROJECT - ONE MORE TIME
# 79위 Hearts2Hearts (하츠투하츠) - FOCUS
# 80위 BLACKPINK - GO
# 81위 DAY6 (데이식스) - Welcome to the Show
# 82위 태양 - LIVE FAST DIE SLOW
# 83위 RESCENE (리센느) - Runaway
# 84위 방탄소년단 - Body to Body
# 85위 Saja Boys - Soda Pop
# 86위 BABYMONSTER - 춤 (CHOOM)
# 87위 박다혜 - 시작의 아이 ❍
# 88위 IVE (아이브) - REBEL HEART
# 89위 TWS (투어스) - 첫 만남은 계획대로 되지 않아
# 90위 LE SSERAFIM (르세라핌) - HOT
# 91위 오반(OVAN) - Flower
# 92위 BOYNEXTDOOR - 오늘만 I LOVE YOU
# 93위 KiiiKiii (키키) - I DO ME
# 94위 투모로우바이투게더 - 하루에 하루만 더 (Stick With You)
# 95위 아일릿(ILLIT) - NOT CUTE ANYMORE
# 96위 AKMU(악뮤) - 봄 색깔
# 97위 IVE (아이브) - XOXZ
# 98위 Hearts2Hearts (하츠투하츠) - STYLE
# 99위 트라이앵글 - Love is
# 100위 아이유(IU) - Love wins all

# %% [markdown]
# 특정 폴더에 저장된 파일 이름 가져오기

# %%
import os

# %%
fileList = os.listdir('./output/')
print(fileList)
print(type(fileList))

for file in fileList:
    print(file[:-4]) # 확장명이 무조건 3글자일 때
    print(file.split('.')[0]) # 확장명 길이가 가변적일 때
    print(file[:file.rfind('.')]) # 파일 이름에 '.'이 여러개이고 확장명 길이가 가변적일 때
    print(file[:file.rindex('.')])
# Out:
# ['bugsTOP100.txt']
# <class 'list'>
# bugsTOP100
# bugsTOP100
# bugsTOP100
# bugsTOP100
