# %% [markdown]
# 함수로 데이터를 전달할 때 데이터가 전달될 인수를 지정할 수 있다.

# %%
def func3(a, b, c):
    print(f'{a} + {b} + {c} = {a + b + c}')

# %%
# 데이터를 함수로 전달할 때 인수를 지정하지 않으면 처음부터 차례대로 데이터가 함수로 전달된다.
func3(100, 200, 300)
# Out:
# 100 + 200 + 300 = 600

# %%
# 함수를 호출할 때 데이터가 전달될 인수를 지정할 수 있다.
func3(a=100, b=200, c=300)
# Out:
# 100 + 200 + 300 = 600

# %%
# 인수를 지정해서 함수를 호출하면 가인수의 순서와 관계없이 사용할 수 있다.
func3(b=100, c=200, a=300)
# Out:
# 300 + 100 + 200 = 600

# %%
# 인수를 지정해서 함수를 호출할 때 가인수 목록에 있는 인수를 지정해야하고 가인수 목록에 없으면 에러가 발생된다.
func3(b=100, c=200, d=300)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # 인수를 지정해서 함수를 호출할 때 가인수 목록에 있는 인수를 지정해야하고 가인수 목록에 없으면 에러가 발생된다.
# ----> 2 func3(b=100, c=200, d=300)
#
# TypeError: func3() got an unexpected keyword argument 'd'

# %%
# 인수를 지정해서 함수를 호출할 때 인수를 부분적으로 지정하면 에러가 발생된다.
func3(a=100, b=200, 300)
# Out:
#   Cell In[11], line 2
#     func3(a=100, b=200, 300)
#                            ^
# SyntaxError: positional argument follows keyword argument
