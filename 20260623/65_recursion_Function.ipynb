# %% [markdown]
# factorial을 계산하는 일반 함수

# %%
def factorial(number):
    fact = 1
    for i in range(1, number + 1):
        fact *= i
    return fact

# %%
number = int(input('숫자를 입력하세요: '))
fact = factorial(number)
print(fact)
# Out:
# 숫자를 입력하세요: 5
# 120

# %% [markdown]
# factorial을 계산하는 recursion 함수

# %%
def factorialRecursion(number):
    if number == 1:
        return 1
    return number * factorialRecursion(number - 1)

# %% [markdown]
# number에 5가 넘어왔을때 factorialRecursion 함수가 실행되는 순서
#
# 5 * factorialRecursion(4)
# 5 * (4 * factorialRecursion(3))
# 5 * (4 * (3 * factorialRecursion(2)))
# 5 * (4 * (3 * (2 * factorialRecursion(1))))
# 5 * (4 * (3 * (2 * (1))))
#
# =================================================================================================
#
# 5 * (4 * (3 * (2 * (1))))
# 5 * (4 * (3 * (2 * 1)))
# 5 * (4 * (3 * 2))
# 5 * (4 * 6)
# 5 * 24
# 120

# %%
print(factorialRecursion(5))
# Out:
# 120
