# %%
from lib.queueModule import Queue
queue = Queue()
queue.view()
# Out:
# 큐에 저장된 데이터 => 없음

# %%
menu = 0
while menu != 4:
    while True:
        print('=' * 33)
        print(' 1.add  2.remove  3.view  4.종료 ')
        print('=' * 33)
        menu = int(input('원하는 메뉴를 입력하고 enter를 누르세요: '))
        if menu in [1, 2, 3, 4]:
            break
        else:
            print('메뉴는 1 ~ 4 사이의 값만 입력해야 합니다.')
        # ===== if
    # ===== while
    
    if menu == 1:
        data = input('큐에 저장할 데이터를 입력하세요: ')
        queue.add(data)
    elif menu == 2:
        queue.remove()
    elif menu == 3:
        queue.view()
    # ===== if
# ===== while
print('프로그램을 종료합니다. 바이바이~~~~~')
# Out:
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 111
# 큐에 111를(을) 저장합니다. rear = 1, front = 0
# 큐에 저장된 데이터 => 111
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 666
# 큐에 666를(을) 저장합니다. rear = 2, front = 0
# 큐에 저장된 데이터 => 111 666
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 888
# 큐에 888를(을) 저장합니다. rear = 3, front = 0
# 큐에 저장된 데이터 => 111 666 888
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 111
# 111는(은) 중복된 데이터입니다.
# 큐에 저장된 데이터 => 111 666 888
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 444
# 큐에 444를(을) 저장합니다. rear = 4, front = 0
# 큐에 저장된 데이터 => 111 666 888 444
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 999
# 큐에 999를(을) 저장합니다. rear = 5, front = 0
# 큐에 저장된 데이터 => 111 666 888 444 999
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 222
# overflow 발생... 큐가 가득차서 222를(을) 저장할 수 없습니다.
# 큐에 저장된 데이터 => 111 666 888 444 999
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 3
# 큐에 저장된 데이터 => 111 666 888 444 999
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 2
# 큐에서 111를(을) 제거합니다. rear = 5, front = 1
# 큐에 저장된 데이터 => 666 888 444 999
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 2
# 큐에서 666를(을) 제거합니다. rear = 5, front = 2
# 큐에 저장된 데이터 => 888 444 999
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 2
# 큐에서 888를(을) 제거합니다. rear = 5, front = 3
# 큐에 저장된 데이터 => 444 999
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 2
# 큐에서 444를(을) 제거합니다. rear = 5, front = 4
# 큐에 저장된 데이터 => 999
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 2
# 큐에서 999를(을) 제거합니다. rear = 5, front = 5
# 큐에 저장된 데이터 => 없음
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 2
# 큐에 저장된 데이터가 없습니다.
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 3
# 큐에 저장된 데이터 => 없음
# =================================
#  1.add  2.remove  3.view  4.종료
# =================================
# 원하는 메뉴를 입력하고 enter를 누르세요: 4
# 프로그램을 종료합니다. 바이바이~~~~~
